# %%
from src.methods.dependencies import *
from src.methods.base import BaseMethod
from observable_jupyter import embed
from src.methods.visualizer import Visualizer

# %%
vis = Visualizer(
    adata=fr'/home/hpc/mfn3/mfn3100h/merscope/merscope-analysis-pipeline/data/clustered_adata.h5ad', 
    input_cell_by_gene=fr'/home/hpc/mfn3/mfn3100h/merscope/mouseLiverData/cell_by_gene.csv', 
    ref_marker_panel=fr'/home/hpc/mfn3/mfn3100h/merscope/41421_2021_266_MOESM1_ESM.xlsx'
).run()

# %%
embed('@vizgen/umap-spatial-heatmap-single-cell-0-3-1', cells=['viewof cgm', 'dashboard'], inputs=vis, display_logo=False)
